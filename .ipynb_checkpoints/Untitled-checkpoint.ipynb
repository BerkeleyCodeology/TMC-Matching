# %%
import pandas as pd
import numpy as np

# %%
x = pd.read_csv("tutors.csv")
y = pd.read_csv("students.csv")


# Group by
l = y[['School', 'Instrument']].groupby(['Instrument']).agg(np.size)
l

# Pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a0fb5e18ffbe> in <module>
#       4
#       5 # Group by
# ----> 6 l = y[['School', 'Instrument']].groupby(['Instrument']).agg(np.size)
#       7 l
#       8
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
# ...

# %%
# Personal Data Frame Merge
left = pd.DataFrame({'Name': ['Stacy', 'John'], 'Age': [17, 16]})
right = pd.DataFrame({'Name': ['Stacy', 'John'], 'Grade': [12, 11]})
pd.merge(left, right, on='Name')
# Out:
#     Name  Age  Grade
# 0  Stacy   17     12
# 1   John   16     11

# %%
# Adding a column
col = y["Email Address"].str.len();
y["name_lengths"] = col
y
# Out:
#              Timestamp              Email Address           Confirm Email  \
# 0   4/13/2020 11:08:45              ffs@gmail.com           ffs@gmail.com
# 1   4/13/2020 11:10:15          jstalin@gmail.com       jstalin@gmail.com
# 2   4/13/2020 11:11:33               gg@gmail.com            gg@gmail.com
# 3   4/13/2020 11:13:28              yhs@gmail.com           yhs@gmail.com
# 4   4/13/2020 11:14:53              tyg@gmail.com           tyg@gmail.com
# 5   4/13/2020 11:16:37               tt@gmail.com            tt@gmail.com
# 6   4/13/2020 11:28:17               lm@gmail.com            lm@gmail.com
# 7   4/13/2020 13:47:04      ahmed.baqai@gmail.com   ahmed.baqai@gmail.com
# 8   4/13/2020 13:48:06      ahmed.baqai@gmail.com   ahmed.baqai@gmail.com
# 9   4/13/2020 13:49:18      ahmed.baqai@gmail.com   ahmed.baqai@gmail.com
# 10  4/13/2020 13:50:33      ahmed.baqai@gmail.com   ahmed.baqai@gmail.com
# 11  4/13/2020 13:57:39      ahmed.baqai@gmail.com   ahmed.baqai@gmail.com
# ...

# %%
x
# Out:
#              Timestamp             Email Address             Name  \
# 0   4/13/2020 13:10:59  shaylandias@berkeley.edu           George
# 1   4/13/2020 13:12:06  shaylandias@berkeley.edu            Rohan
# 2   4/13/2020 13:13:35  shaylandias@berkeley.edu             Jose
# 3   4/13/2020 13:14:42  shaylandias@berkeley.edu     zz@gmail.com
# 4   4/13/2020 13:15:54  shaylandias@berkeley.edu            Lizzy
# 5   4/13/2020 14:04:53         abaq@berkeley.edu      Ahmed Baqai
# 6   4/13/2020 14:06:27         abaq@berkeley.edu   James McDonald
# 7   4/13/2020 14:08:03         abaq@berkeley.edu       Tony Stark
# 8   4/13/2020 14:09:16         abaq@berkeley.edu        Arnav Rao
# 9   4/13/2020 14:11:07         abaq@berkeley.edu      Ryan Nadeem
# 10  4/13/2020 23:30:19  cindyxzhang@berkeley.edu  Bob the Builder
# 11  4/13/2020 23:31:49  cindyxzhang@berkeley.edu       askfhalkjh
# 12  4/13/2020 23:36:15  cindyxzhang@berkeley.edu              gah
# ...

# %%
# Adding a column
col = y["Email Address"].str.len().astype(int);
y["name_lengths"] = col
y
